# %%
#upper()

"harshanth".upper()
# Out:
# 'HARSHANTH'

# %%
"nelamangala".upper()
# Out:
# 'NELAMANGALA'

# %%
#lstrip()

"\n\tworld".lstrip()
# Out:
# 'world'

# %%
"$$$money".lstrip("$")
# Out:
# 'money'

# %%
#rfind()

"harshanth".rfind("h")
# Out:
# 8

# %%
"laptop".rfind("p")
# Out:
# 5

# %%
#replace()

"run all".replace("all","together")
# Out:
# 'run together'

# %%
"abcd".replace("abcd","1234")
# Out:
# '1234'

# %%
#rsplit

"a b c d ".rsplit()
# Out:
# ['a', 'b', 'c', 'd']

# %%
"python-jupyter".rsplit("-",1)
# Out:
# ['python', 'jupyter']

# %%
#rstrip()

"data...\n".rstrip()
# Out:
# 'data...'

# %%
"maths####".rstrip("#")
# Out:
# 'maths'

# %%
#split9

"1 2 3 4".split()
# Out:
# ['1', '2', '3', '4']

# %%
"bus-car".split("-")
# Out:
# ['bus', 'car']

# %%
#startswith

"python".startswith("py")
# Out:
# True

# %%
"jupyter".startswith("up")
# Out:
# False

# %%
#strip

"real world".strip()
# Out:
# 'real world'

# %%
"##start##".strip("#")
# Out:
# 'start'

# %%
#title()

"chapter 1".title()
# Out:
# 'Chapter 1'

# %%
"social studies".title()
# Out:
# 'Social Studies'

# %%
#splitness()

"a\nc\nd".splitlines()
# Out:
# ['a', 'c', 'd']

# %%
"line1\rline2".splitlines()
# Out:
# ['line1', 'line2']

# %%
#casefold

"certisured".casefold()
# Out:
# 'certisured'

# %%
"harshanth".casefold()
# Out:
# 'harshanth'

# %%
#capitalize

"harshanth".capitalize()
# Out:
# 'Harshanth'

# %%
"CERTISURED".capitalize()
# Out:
# 'Certisured'

# %%
#centre

"harshanth".center(15,"*")
# Out:
# '***harshanth***'

# %%
"biology".center(18,"#")
# Out:
# '#####biology######'

# %%
#count

"banana".count("a")
# Out:
# 3

# %%
"agsjsgka".count("z")
# Out:
# 0

# %%
#encode()

"hello".encode()
# Out:
# b'hello'

# %%
"data".encode("ascii")
# Out:
# b'data'

# %%
#endswwith()

"harshanth".endswith("i")
# Out:
# False

# %%
"certisured".endswith("d")
# Out:
# True

# %%
#find()

"omegaa".find("d")
# Out:
# -1

# %%
"darshan".find("a")
# Out:
# 1

# %%
#format()

"my name is {}".format("josh")
# Out:
# 'my name is josh'

# %%
"i am {} years old".format(21)
# Out:
# 'i am 21 years old'

# %%
#index()

"pineapple".index("p")
# Out:
# 0

# %%
"mercedes".index("r")
# Out:
# 2

# %%
#isalnum()

"abc2435".isalnum()
# Out:
# True

# %%
"bcd@".isalnum()
# Out:
# False

# %%
#isalpha()

"maths".isalpha()
# Out:
# True

# %%
"vivo v25".isalpha()
# Out:
# False

# %%
#isdecimal()

"1234".isdecimal()
# Out:
# True

# %%
"2526.76".isdecimal()
# Out:
# False

# %%
#isdigit

"8088".isdigit()
# Out:
# True

# %%
"567.89".isdigit()
# Out:
# False

# %%
#isidentifier()

"characters".isidentifier()
# Out:
# True

# %%
"char123".isidentifier()
# Out:
# True

# %%
"123char".isidentifier()
# Out:
# False

# %%
#islower

"MATHS".islower()
# Out:
# False

# %%
"maths".islower()
# Out:
# True

# %%
#isnumeric()

"5678".isnumeric()
# Out:
# True

# %%
"189.67".isnumeric()
# Out:
# False

# %%
#isspace

"\h\t".isspace()
# Out:
# False

# %%
"a\b\c".isspace()
# Out:
# False

# %%
#istitle()

"day today".istitle()
# Out:
# False

# %%
"python is fun".istitle()
# Out:
# False

# %%
#isprintable

"hello".isprintable()
# Out:
# True

# %%
"abc\n".isprintable()
# Out:
# False

# %%
#isupper()

"MATHS".isupper()
# Out:
# True

# %%
"bharat".isupper()
# Out:
# False

# %%
#join

"-".join(["b","c"])
# Out:
# 'b-c'

# %%
",".join("123")
# Out:
# '1,2,3'

# %%
#lower()

"PYTHON".lower()
# Out:
# 'python'

# %%
"CHATGPT".lower()
# Out:
# 'chatgpt'
